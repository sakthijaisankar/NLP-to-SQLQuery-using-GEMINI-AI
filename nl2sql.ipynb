# %% [markdown]
# ## Importing Datasets

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Sample file2.csv')

# %%
df
# Out:
#      ASPEN_FACID  ELMS_FACID                                       FACNAME  \
# 0      123456789   456321789                           UCLA Medical Center
# 1      452698713   751023659                          Stanford Health Care
# 2     7631441012  3440699841                           UCSF Medical Center
# 3     4430315500  6679820500  Kaiser Permanente Los Angeles Medical Center
# 4     2152951532  7729759522        Sutter Health Sacramento Sierra Region
# ..           ...         ...                                           ...
# 305   6063073805  7759146527                  Huntington Memorial Hospital
# 306   5482961496  6684475957                       Sharp Memorial Hospital
# 307    178271878  8276433627            Scripps Memorial Hospital La Jolla
# 308    785628127  4574128838             California Pacific Medical Center
# 309   1703794935  3926315197                   Cedars-Sinai Medical Center
#
# ...

# %%
df2 = pd.read_csv('Sample file1.csv')

# %%
df2
# Out:
#      ASPEN_FACID  ELMS_FACID                            FACNAME  \
# 0      123456789   456321789    Indira Multispeciality Hospital
# 1      452698713   751023659                       CMC Hospital
# 2      123548658   271039692                    Global Healcare
# 3      557766221   545380969                     AGS Healthcare
# 4      546464646   720142184                  Stanford Healcare
# ..           ...         ...                                ...
# 224    658794500   558212288         Scripps La Jolla Hospitals
# 225    292576947   281844367               Keck Hospital of USC
# 226    141122328   959605873                Huntington Hospital
# 227    235709305   360598416            Sharp Memorial Hospital
# 228    981058959   933224870  California Pacific Medical Center
#
#                         FAC_TYPE FAC_TYPE_CODE FAC_STATUS_TYPE_CODE  \
# 0                            NaN           MSH                 Open
# ...

# %% [markdown]
# ## Making Database by inserting Dataset using SQLITE3

# %%
import sqlite3

# %%
# Create a connection to the SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect('my_database.db')

# %% [markdown]
# inserting dataset into database and save it in localhost

# %%
# Save df and df1 as tables in the database
df.to_sql('df', conn, if_exists='replace', index=False)
df1.to_sql('df1', conn, if_exists='replace', index=False)

conn.commit()
# Out:
# 310

# %%
# Commit changes and close the connection
conn.commit()
conn.close()

# %%
import pandas as pd
conn = sqlite3.connect('my_database.db')

# %%
cursor = conn.cursor()

# Execute a query to get the list of tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Fetch all rows from the cursor
tables = cursor.fetchall()

# Print the list of tables
for table in tables:
    print(table[0])
# Out:
# table_name_for_df
# table_name_for_df1
# df
# df1

# %%
dataset = pd.read_sql_query("SELECT * FROM table_name_for_df", conn)
print(dataset)
# Out:
#      ASPEN_FACID  ELMS_FACID                                       FACNAME  \
# 0      123456789   456321789                           UCLA Medical Center
# 1      452698713   751023659                          Stanford Health Care
# 2     7631441012  3440699841                           UCSF Medical Center
# 3     4430315500  6679820500  Kaiser Permanente Los Angeles Medical Center
# 4     2152951532  7729759522        Sutter Health Sacramento Sierra Region
# ..           ...         ...                                           ...
# 305   6063073805  7759146527                  Huntington Memorial Hospital
# 306   5482961496  6684475957                       Sharp Memorial Hospital
# 307    178271878  8276433627            Scripps Memorial Hospital La Jolla
# 308    785628127  4574128838             California Pacific Medical Center
# 309   1703794935  3926315197                   Cedars-Sinai Medical Center
#
# ...

# %% [markdown]
# ## Importing GooglePalm (Gemini AI) using LangChain

# %%
from langchain.llms import GooglePalm

api_key = 'AIzaSyByc3eRhh2tzz3zw5OX59uvxYswELOa3H4'
llm = GooglePalm(google_api_key=api_key, temperature=0.2)

# %%
from langchain.utilities import SQLDatabase
from langchain_experimental.sql import SQLDatabaseChain

# %%
cursor = conn.cursor()

# %%
# connect SQLITE database to the jupyter Notebook
db = SQLDatabase.from_uri("sqlite:///my_database.db")

# %%
# connect SQLdatabase to LLM model
from langchain_experimental.sql import SQLDatabaseChain

db_chain = SQLDatabaseChain.from_llm(llm, db, verbose=True)
qnsl1 = db_chain('give me data of FAC_TYPE_CODE MSH')
# Out:
# > Entering new SQLDatabaseChain chain...
# give me data of FAC_TYPE_CODE MSH
# SQLQuery:SELECT * FROM df1 WHERE FAC_TYPE_CODE = 'MSH'
# ...

# %%
from io import StringIO
import sys

# Redirect stdout to a variable
stdout_saved = sys.stdout
sys.stdout = StringIO()

# Example function call that prints verbose output
db_chain = SQLDatabaseChain.from_llm(llm, db, verbose=True)
qnsl1 = db_chain('give me data of FAC_TYPE_CODE MSH')

# %%
# Get the printed output
output = sys.stdout.getvalue()

# Reset stdout to its original value
sys.stdout = stdout_saved

# %%
import re

# %%
# Define a regex pattern to match the SQLQuery line
pattern = r"SQLQuery:(.*)"

# Use regex to find the SQLQuery line
match = re.search(pattern, output)

# Extract the SQLQuery from the match
sql_query = match.group(1).strip() if match else None

# %%
# Print the SQLQuery
print(sql_query)
# Out:
# SELECT * FROM df1 WHERE FAC_TYPE_CODE = 'MSH' LIMIT 5

# %%
sql_query = sql_query.strip()

# %%
import re

# Define a regular expression pattern to match ANSI escape codes
ansi_escape_pattern = re.compile(r'\x1b\[\d{1,2}(;\d{1,2}){0,2}m')

# Remove ANSI escape codes from the string
clean_sql_query = ansi_escape_pattern.sub('', sql_query)
# Out:
# SELECT * FROM df1 WHERE FAC_TYPE_CODE = 'MSH' LIMIT 5

# %%
clean_sql_query
# Out:
# "SELECT * FROM df1 WHERE FAC_TYPE_CODE = 'MSH' LIMIT 5"

# %%
pd.read_sql_query(clean_sql_query, conn)
# Out:
#    ASPEN_FACID  ELMS_FACID                          FACNAME  \
# 0    123456789   456321789  Indira Multispeciality Hospital
# 1    693704678   737089478  Indira Multispeciality Hospital
# 2    397746978   442246537  Indira Multispeciality Hospital
# 3    659613559   662235771  Indira Multispeciality Hospital
# 4    201148102   794492560  Indira Multispeciality Hospital
#
#                   FAC_TYPE FAC_TYPE_CODE FAC_STATUS_TYPE_CODE  \
# 0                     None           MSH                 Open
# 1  Multispecialty Hospital           MSH                 Open
# 2  Multispecialty Hospital           MSH                 Open
# 3  Multispecialty Hospital           MSH                 Open
# 4  Multispecialty Hospital           MSH                 Open
#
#            FAC_ADDRESS FAC_CITY  FAC_ZIP COUNTY_NAME            DISTRICT_NAME
# 0  123, Vellore, India  Vellore    12345     Vellore  Vellore District Office
# ...

# %%
df1[df1['FAC_TYPE_CODE'] == 'MSH']
# Out:
#      ASPEN_FACID  ELMS_FACID                          FACNAME  \
# 0      123456789   456321789  Indira Multispeciality Hospital
# 39     693704678   737089478  Indira Multispeciality Hospital
# 78     397746978   442246537  Indira Multispeciality Hospital
# 117    659613559   662235771  Indira Multispeciality Hospital
# 156    201148102   794492560  Indira Multispeciality Hospital
# 195    491441593   878450599  Indira Multispeciality Hospital
#
#                     FAC_TYPE FAC_TYPE_CODE FAC_STATUS_TYPE_CODE  \
# 0                        NaN           MSH                 Open
# 39   Multispecialty Hospital           MSH                 Open
# 78   Multispecialty Hospital           MSH                 Open
# 117  Multispecialty Hospital           MSH                 Open
# 156  Multispecialty Hospital           MSH                 Open
# 195  Multispecialty Hospital           MSH                 Open
#
#              FAC_ADDRESS FAC_CITY  FAC_ZIP COUNTY_NAME  \
# ...

# %%
# Redirect stdout to a variable
stdout_saved = sys.stdout
sys.stdout = StringIO()

qnsl2 = db_chain('can you give me data of hospitals that are vellore dont limit to 5')
# Out:
# SELECT * FROM df1 WHERE FAC_CITY = "Vellore"

# %%
# Get the printed output
output = sys.stdout.getvalue()

# Reset stdout to its original value
sys.stdout = stdout_saved

# Define a regex pattern to match the SQLQuery line
pattern = r"SQLQuery:(.*)"

# Use regex to find the SQLQuery line
match = re.search(pattern, output)

# Extract the SQLQuery from the match
sql_query = match.group(1).strip() if match else None

sql_query = sql_query.strip()

# Define a regular expression pattern to match ANSI escape codes
ansi_escape_pattern = re.compile(r'\x1b\[\d{1,2}(;\d{1,2}){0,2}m')

# Remove ANSI escape codes from the string
clean_sql_query = ansi_escape_pattern.sub('', sql_query)

print(clean_sql_query)

# %%
pd.read_sql_query(clean_sql_query, conn)
# Out:
#     ASPEN_FACID  ELMS_FACID                          FACNAME  \
# 0     123456789   456321789  Indira Multispeciality Hospital
# 1     452698713   751023659                     CMC Hospital
# 2     693704678   737089478  Indira Multispeciality Hospital
# 3     722861313   916142850                     CMC Hospital
# 4     397746978   442246537  Indira Multispeciality Hospital
# 5     809592544   203658176                     CMC Hospital
# 6     659613559   662235771  Indira Multispeciality Hospital
# 7     957427507   364815106                     CMC Hospital
# 8     201148102   794492560  Indira Multispeciality Hospital
# 9     506530665   924219502                     CMC Hospital
# 10    491441593   878450599  Indira Multispeciality Hospital
# 11    125902198   588484261                     CMC Hospital
#
#                    FAC_TYPE FAC_TYPE_CODE FAC_STATUS_TYPE_CODE  \
# 0                      None           MSH                 Open
# ...
